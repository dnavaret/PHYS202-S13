# %% [markdown]
# Publication ready plot template===============================Simple graphing template for matplotlib functions and data plots.

# %% [markdown]
# Line Plots

# %%
import numpy as np

# %%
y = arange(-5.0,5.0+1.0,1.0)E = np.array(cosh(y))print Ep = np.array(sinh(y))print p
# Out:
# [ 74.20994852  27.30823284  10.067662     3.76219569   1.54308063   1.   1.54308063   3.76219569  10.067662    27.30823284  74.20994852][-74.20321058 -27.2899172  -10.01787493  -3.62686041  -1.17520119   0.   1.17520119   3.62686041  10.01787493  27.2899172   74.20321058]

# %% [markdown]
# (d)

# %%
plot(y,E)plot(y,p)#need ax==gca() to call the other commandsax = gca()#sets colorax.spines['right'].set_color('none')ax.spines['top'].set_color('none')#sets line positionax.spines['left'].set_position(('data', 0))ax.spines['bottom'].set_position(('data', 0))ax.spines['top'].set_position(('data', 0))ax.spines['right'].set_position(('data', -1))#label x and yxlabel("                                                                                                             x")ylabel("                                                                       y")

# %% [markdown]
# (e1)

# %%
#Plotting sinh and cosh#subplot(m,n,P) creates an MxN matrix, and places the following plot in the P positionsubplot(1,2,1); plot(y,E)title('Cosh')subplot(1,2,2); plot(y,p)title('Sinh')#need ax==gca() to call the other commandsax = gca()#sets colorax.spines['right'].set_color('none')ax.spines['top'].set_color('none')#sets line positionax.spines['left'].set_position(('data', 0))ax.spines['bottom'].set_position(('data', 0))ax.spines['top'].set_position(('data', 0))ax.spines['right'].set_position(('data', -1))#label x and yxlabel("                                                   x")ylabel("                                                       y")

# %% [markdown]
# (e_2)

# %%
n = 200X = random.normal(0,1,n)Y = random.normal(0,1,n)plot(X,Y)#need ax==gca() to call the other commandsax = gca()#sets colorax.spines['right'].set_color('none')ax.spines['top'].set_color('none')#sets line positionax.spines['left'].set_position(('data', 0))ax.spines['bottom'].set_position(('data', 0))ax.spines['top'].set_position(('data', 0))ax.spines['right'].set_position(('data', -1))#label x and yxlabel("                                                                                                          x")ylabel("                                                                        y")
