# %% [markdown]
# Publication Quality Graphix===========================

# %% [markdown]
# Number 1

# %% [markdown]
# \begin{equation}y=mx+b\end{equation}

# %% [markdown]
# \begin{equation}\psi_k(x)= A(\frac{ik-a\tanh(ax)}{ik+a})e^{+ikx}\end{equation}

# %% [markdown]
# \begin{equation}\upsilon_1 = m_2\sqrt{\frac{2G}{M}(\frac{1}{r}-\frac{1}{r_0})}\end{equation}

# %% [markdown]
# \begin{equation}f(\theta) = \frac{\hbar}{p}\sum_{\ell=0}^\infty(2\ell+1)e^{i\delta_\ell}\sin\delta_\ell{P_\ell}(cos\theta)\end{equation}

# %% [markdown]
# \begin{equation}\frac{d\sigma}{d\Omega}=\frac{k\pi^2(\pi-\theta)}{mu_0^2\theta^2(2\pi-\theta)^2\sin\theta}\end{equation}

# %% [markdown]
# \begin{equation}\langle{f}\rangle=\frac{1}{\tau}\int_0^\tau f(t)dt.\end{equation}

# %% [markdown]
# \begin{equation}\Omega_S=\omega\frac{\sin\alpha}{\sin\theta}=\frac{L}{\lambda_1}=\omega\frac{\sqrt{\lambda_3^2+(\lambda_1^2-\lambda_3^2)\sin\alpha}}{\lambda_1}\end{equation}

# %% [markdown]
# Number 2

# %%
i=1jk = 0k1 = .25k2 = 1k3 = 4t = np.arange(-pi, pi, .00001)s = (np.tanh(t)**2 + k) / (1 + k)r = (np.tanh(t)**2 + k1) / (1 + k1)p = (np.tanh(t)**2 + k2) / (1 + k2)n = (np.tanh(t)**2 + k3) / (1 + k3)f = -(1 / np.cosh(t))plot(t,f, label = "$U(x)$")plot(t,s, label = "$\psi^2,k=0$", linestyle = "--")plot(t,r, label = "$\psi^2,k=.5$", linestyle = "-.")plot(t,p, label = "$\psi^2,k=1$", linestyle = ";")plot(t,n, label = "$\psi^2,k=2$", linestyle = "-")legend(loc = "lower left")xlabel("$x$(rad)")ylabel("U(x)$\psi^2$")xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fae09528450>,  <matplotlib.axis.XTick at 0x26a67d0>,  <matplotlib.axis.XTick at 0x26aeed0>,  <matplotlib.axis.XTick at 0x26a8510>,  <matplotlib.axis.XTick at 0x26a8b90>], <a list of 5 Text xticklabel objects>)

# %% [markdown]
# Number 3

# %% [markdown]
# (a)

# %%
data = loadtxt("/home/david/Downloads/sunspots.txt")x=data[:,0]y=data[:,1]plot(x, y)xlabel("Year")

# %% [markdown]
# (b)

# %%
data = loadtxt("/home/david/Downloads/sunspots.txt")x=data[:,0]y=data[:,1]plot(x[:1000], y[:1000:])xlabel("Year")

# %% [markdown]
# (c)

# %%
data = loadtxt("/home/david/Downloads/sunspots.txt")x=data[:,0]y=data[:,1]plot(x[:1000], y[:1000:])a = np.zeros(1000)b = np.zeros(1000)avg = np.zeros(1000)tot = 0for i in range(1000):    a[i] = x[i]    b[i] = y[i]    tot += y[i]    avg[i] = tot / iplot(a, b, lw = 1, label = "Sunspots")plot(a, avg, lw = 5, label = "Average")xlabel("Months")ylabel("Number of Sunspots")title("1st 1000 Sunpots/month since 1749")legend()show()
# Out:
# -c:15: RuntimeWarning: divide by zero encountered in double_scalars

# %% [markdown]
# Number 4

# %% [markdown]
# (a)

# %%
data = loadtxt("/home/david/Downloads/stars.txt")x=data[:,0]y=data[:,1]plot(x[:1000:], y[:1000:])

# %% [markdown]
# (b)

# %%
data = loadtxt("/home/david/Downloads/stars.txt")x=data[:,0]y=data[:,1]plot(x[:1000:], y[:1000:])xlim([5,20])ylim([0,4250])#switching to make proper orientationplot(y[:1000:], x[:1000:])

# %%
#that cluster of stars at the top right is a bunch #of giants and supergiants that have similar properties#and start the main sequence until you get to the smaller stars at the bottom
