# %% [markdown]
# TUESDAY 4/23 NOTES==================3-D Plotting and functions --------------------------

# %%
import math import numpy as np

# %% [markdown]
# how to inspect shape in size x.ndim y.shape

# %%
#make the x-y grid to cover the plane -2<x<2 and -2<y<2dx = 0.05dy = 0.05x,y = meshgrid(arange(-2.,2.,dx),arange(-2.,2.,dy))x.ndimy.shape
# Out:
# (80, 80)

# %% [markdown]
# Create 2 dimensional array to define functions on and two dimensional figures

# %% [markdown]
# Electric Dipole Potential-------------------------

# %% [markdown]
# \begin{equation}V_(x,y) = \frac{kq}{\sqrt{x^2+(y-d)^2}}-\\frac{kq}{\sqrt{x^2+(y+d)^2}}\end{equation}

# %%
#make function Vxyk=1; q=1; d=1#put a period after the 2 for the 1/2 exponent, something about floatV=(k*q/(x**2 + (y - d)**2)**(1/2.) - (k*q/(x**2 + (y+d)**2)**(1/2.)))print V
# Out:
# [[-0.1698635  -0.17683544 -0.18414007 ..., -0.19179341 -0.18414007  -0.17683544] [-0.1710596  -0.17823428 -0.18576295 ..., -0.19366377 -0.18576295  -0.17823428] [-0.17209427 -0.17946759 -0.18721662 ..., -0.19536183 -0.18721662  -0.17946759] ...,  [ 0.17295258  0.180519    0.18848319 ...,  0.19686802  0.18848319   0.180519  ] [ 0.17209427  0.17946759  0.18721662 ...,  0.19536183  0.18721662   0.17946759] [ 0.1710596   0.17823428  0.18576295 ...,  0.19366377  0.18576295   0.17823428]]

# %%
from mpl_toolkits.mplot3d import Axes3Dfig = figure()ax = fig.gca(projection='3d')p= ax.plot_surface(x, y, V, rstride=1, cstride=1, linewidth=0, cmap=cm.coolwarm)

# %%
help(Axes3D.plot_surface)
# Out:
# Help on method plot_surface in module mpl_toolkits.mplot3d.axes3d:plot_surface(self, X, Y, Z, *args, **kwargs) unbound mpl_toolkits.mplot3d.axes3d.Axes3D method    Create a surface plot.        By default it will be colored in shades of a solid color,    but it also supports color mapping by supplying the *cmap*    argument.        ============= ================================================    Argument      Description    ============= ================================================    *X*, *Y*, *Z* Data values as 2D arrays    *rstride*     Array row stride (step size)    *cstride*     Array column stride (step size)    *color*       Color of the surface patches    *cmap*        A colormap for the surface patches.    *facecolors*  Face colors for the individual patches    *norm*        An instance of Normalize to map values to colors    *vmin*        Minimum value to map    *vmax*        Maximum value to map    *shade*       Whether to shade the facecolors    ============= ======
# ...

# %%
fig = figure()ax = fig.gca(projection='3d')#p: plots#cmap is differentp= ax.plot_surface(x, y, V, rstride=1, cstride=1, linewidth=0, cmap=cm.jet)

# %%
fig = figure()ax = fig.gca(projection='3d')#tab after cmap=cm. gives optionsp= ax.plot_surface(x, y, V, rstride=1, cstride=1, linewidth=0, cmap=cm.Greens_r)

# %%
fig = figure()ax = fig.gca(projection='3d')p= ax.plot_surface(x, y, V, rstride=1, cstride=1, linewidth=0, cmap=cm.cubehelix)

# %%
fig = figure()ax = fig.gca(projection='3d')p= ax.plot_surface(x, y, V, rstride=1, cstride=1, linewidth=0, cmap=cm.coolwarm)#adds color bar to the rightcb = fig.colorbar(p, shrink=0.5)

# %%
#makes contour lines of the defined levellevels = array([8, 4, 2, 1, 0.5, 0.25, 0, -0.25, -0.5, -1, -2, -4, -8])contour(x,y,V,levels,cmap=cm.coolwarm)show()

# %% [markdown]
# (1)--------------______________

# %% [markdown]
# Plot $Gxy=e^{(-x^2-y^2)}$

# %% [markdown]
# Range:[-6,6]

# %%
#make function GxyG = exp((-(x**2)-(y**2)))dx = 0.23dy = 0.23x,y = meshgrid(arange(-6.,6.,dx),arange(-6.,6.,dy))fig = figure()ax = fig.gca(projection='3d')p = ax.plot_surface(x, y, G, rstride=1, cstride=1, linewidth=0, cmap=cm.winter)levels = array([8, 4, 2, 1, 0.5, 0.25, 0, -0.25, -0.5, -1, -2, -4, -8])#to plot contour behind lines (could add levels after G) #zdir plots on x plane cset = ax.contour(x, y, G,levels, zdir='x', offset=-6, cmap=cm.winter)

# %% [markdown]
# (2)---___

# %% [markdown]
# Electric Potential of a quadrupole consisting of $q=-1.0 nC$ at both (($x=-2$ and $x=2$), $y=0$) and $q=+1.0 nC$ at both ($x=0$, ($y=-2$ and $y=2$))make a surface plot and a contour plot on the Range:[-4,4], using 101 bins in $x$ and $y$.

# %% [markdown]
# \begin{equation}V_(x,y) = \frac{kq}{\sqrt{x^2+(y-d)^2}}-\\frac{kq}{\sqrt{x^2+(y+d)^2}}\end{equation}

# %%
#make function Vxyk=8987551800; q1=-1*(10**-9); q2=1*(10**-9); d=1#put a period after the 2 for the 1/2 exponent, something about floatV1 = (k*q1/((x+2)**2 + (y - d)**2)**(1/2.) - (k*q1/(x**2 + (y + 2 + d)**2)**(1/2.)))V2 = (k*q2/((x-2)**2 + (y - d)**2)**(1/2.) - (k*q2/(x**2 + (y - 2 + d)**2)**(1/2.)))dx = 0.08dy = 0.08x,y = meshgrid(arange(-4.,4.,dx),arange(-4.,4.,dy))fig = figure()ax = fig.gca(projection='3d')p = ax.plot_surface(x, y, V1, rstride=1, cstride=1, linewidth=0, cmap=cm.BrBG_r)p = ax.plot_surface(x, y, V2, rstride=1, cstride=1, linewidth=0, cmap=cm.BrBG_r)

# %% [markdown]
# (3)---___

# %% [markdown]
# (a)___

# %% [markdown]
# Electric Potential of a Point Charge------------------------------------

# %% [markdown]
# \begin{equation}V_{xy}=\frac{kq}{r}\end{equation}

# %%
"""Takes in arguements for Vxy and outputs a point potential."""def pointPotential(x,y,q,posx,posy):    k=8987551800; q1=-1*(10**-9); q2=1*(10**-9); d=1    Vab=((k*q)/((x**2+y**2)**(1/2.)))    print Vabx=1; y=1print V11
# Out:
# None

# %%
x = 1.; y = 1.V11 = pointPotential(x,y,1e-9,0.,0.)print V11
# Out:
# 6.35515882405None

# %%
x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))Vab = pointPotential(x,y,1e-9,0.,0.)print Vab
# Out:
# [[ 3.17757941  3.22559495  3.27428946 ...,  3.30710904  3.25798498   3.20951244] [ 3.22559495  3.27585506  3.32689793 ...,  3.36134185  3.30979899   3.25901295] [ 3.27428946  3.32689793  3.38040363 ...,  3.41655455  3.36247083   3.30926048] ...,  [ 3.30710904  3.36134185  3.41655455 ...,  3.45389067  3.3980434   3.3431539 ] [ 3.25798498  3.30979899  3.36247083 ...,  3.3980434   3.34482043   3.29243068] [ 3.20951244  3.25901295  3.30926048 ...,  3.3431539   3.29243068   3.24242797]]None

# %% [markdown]
# (b)___

# %%
def dipolePotential(x,y,q,d):    k=8987551800; q1=-1*(10**-9); q2=1*(10**-9); d=1    Vxy=(k*q/(x**2 + (y-d)**2)**(1/2.) - (k*q/(x**2 + (y+d)**2)**(1/2.)))    print Vxyx=1;y=1print V11
# Out:
# [[-1.52665698 -1.6022041  -1.68209807 ..., -1.73789923 -1.65496846  -1.57655087] [-1.53938717 -1.61758022 -1.70045818 ..., -1.7584568  -1.67229388  -1.59100937] [-1.54998969 -1.63076109 -1.71656371 ..., -1.77672638 -1.6873834  -1.60329437] ...,  [ 1.55576088  1.63820032  1.72590493 ...,  1.78748094  1.69606276   1.61015302] [ 1.54670621  1.6266273   1.71146343 ...,  1.77090977  1.68261909   1.59945622] [ 1.53536885  1.61268616  1.69457464 ...,  1.75184346  1.66675364   1.5864192 ]]4.96819644478

# %% [markdown]
# (c)___

# %%
def pointPotential(x,y,q,posx,posy):    k = 8.9875518*10**9 #setting k, q, and d values    q = 1*10**-9    Vab = (k*q)/(x**2 + y**2)**(1/2.) #insert Vxy function    return Vyx #return Vxyx,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))Vab = pointPotential(x,y,1e-9,0.,0.)print Vyxfrom mpl_toolkits.mplot3d import Axes3Dfig = figure()ax = fig.gca(projection = '3d')p = ax.plot_surface(x,y,Vyx, rstride=1, cstride=1, linewidth=0, cmap=cm.coolwarm)
# Out:
# [[ 3.17757941  3.22559495  3.27428946 ...,  3.30710904  3.25798498   3.20951244] [ 3.22559495  3.27585506  3.32689793 ...,  3.36134185  3.30979899   3.25901295] [ 3.27428946  3.32689793  3.38040363 ...,  3.41655455  3.36247083   3.30926048] ...,  [ 3.30710904  3.36134185  3.41655455 ...,  3.45389067  3.3980434   3.3431539 ] [ 3.25798498  3.30979899  3.36247083 ...,  3.3980434   3.34482043   3.29243068] [ 3.20951244  3.25901295  3.30926048 ...,  3.3431539   3.29243068   3.24242797]]

# %%
def dipolePotential(x,y,q,d):    k = 8.9875518*10**9; q = 1*10**-9; Vxy = (k*q/((x)**2 + (y - d)**2)**(1/2.) - (k*q/(x**2 + (y + d)**2)**(1/2.))) #insert Vxy function    return Vxy #return Vxyx,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))Vxy = dipolePotential(x,y,q,d)from mpl_toolkits.mplot3d import Axes3Dfig = figure()ax = fig.gca(projection = '3d')p = ax.plot_surface(x,y,Vxy, rstride=1, cstride=1, linewidth=0, cmap=cm.coolwarm)
